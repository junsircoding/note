# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf

# %%
# 创建一个图元素
message = tf.constant("Welcome!")

# %%
with tf.Session() as tfs:
  print(tfs.run(message).decode())
# Out:
# Welcome!

# %%
v_1 = tf.constant([1,2,3,4]) 
v_2 = tf.constant([2,1,5,3]) 
v_add = tf.add(v_1,v_2)

# %%
with tf.Session() as tfs:
  print(tfs.run([v_1, v_2, v_add]))
# Out:
# [array([1, 2, 3, 4], dtype=int32), array([2, 1, 5, 3], dtype=int32), array([3, 3, 8, 7], dtype=int32)]

# %%
sess = tf.InteractiveSession() 

v_1 = tf.constant([1,2,3,4]) 
v_2 = tf.constant([2,1,5,3]) 

v_add = tf.add(v_1,v_2) 

print(v_add.eval()) 

sess.close()
# Out:
# [3 3 8 7]

# %%
t_2 = tf.constant([4, 3, 2])

# %%
tf.ones_like(t_2)
# Out:
# <tf.Tensor 'ones_like:0' shape=(3,) dtype=int32>

# %%
tf.zeros_like(t_2)
# Out:
# <tf.Tensor 'zeros_like:0' shape=(3,) dtype=int32>
